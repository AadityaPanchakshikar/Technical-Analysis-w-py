# %% [markdown]
# <a href="https://colab.research.google.com/github/AadityaPanchakshikar/Technical-Analysis-w-py/blob/main/Bollinger%2BBands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bollinger Bands

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Mount Google Drive to access files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Trading/Data/SampleNiftyData.csv'
df = pd.read_csv(file_path, parse_dates=["date"], index_col="date")
df.head(2)

# %%
df_part = df.loc["2020"]
range_period = 20
sma = df_part.close.rolling(range_period).mean()
std = df_part.close.rolling(range_period).std()
bollinger_up = sma + std * 2
bollinger_down = sma - std * 2

# %%
index = df_part.index

plt.figure(figsize=(18,10))
plt.plot(sma, label='SMA', c='orange')
plt.plot(index, bollinger_up, label='Bollinger Up', c='g')
plt.plot(index, bollinger_down, label='Bollinger Down', c='g')
close = df_part['close'].tolist()
plt.plot(index, close, label='Close', c='gray')
plt.fill_between(index, bollinger_up, bollinger_down, color = 'g', alpha=0.25)
plt.legend()
